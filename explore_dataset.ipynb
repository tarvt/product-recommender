# %% [markdown]
# #Load User Reviews
# First, we need to convert this JSON Lines data into a more usable format, such as a Pandas DataFrame in Python, to easily extract and organize the desired fields before saving to a CSV file.

# %%
import json
import csv


def jsonl_to_csv(input_file, output_file):
    """
    Converts a JSON Lines file to a CSV file with specified fields.

    Args:
        input_file (str): Path to the input JSON Lines file.
        output_file (str): Path to the output CSV file.
    """
    with open(input_file, 'r') as infile, open(output_file, 'w', newline='', encoding='utf-8') as outfile:
        fieldnames = ['UserId', 'asin', 'parent_asin',
                      'Text', 'TimeStamp', 'Title', 'helpful_vote', 'Score']
        writer = csv.DictWriter(outfile, fieldnames=fieldnames)

        writer.writeheader()

        for line in infile:
            try:
                record = json.loads(line.strip())
                writer.writerow({
                    'UserId': record.get('user_id', ''),
                    'asin': record.get('asin', ''),
                    'parent_asin': record.get('parent_asin', ''),
                    'Text': record.get('text', ''),
                    'TimeStamp': record.get('timestamp', ''),
                    'Title': record.get('title', ''),
                    'helpful_vote': record.get('helpful_vote', ''),
                    'Score': record.get('rating', 0),
                    
                })
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON line: {line.strip()}. Error: {e}")
            except Exception as e:
                print(
                    f"An unexpected error occurred while processing line: {line.strip()}. Error: {e}")

# %%
# Replace with the actual name of your input file
input_filename = r"f:\projects\product-recommender\dataset\All_Beauty.jsonl"
output_filename = r"f:\projects\product-recommender\dataset\Beauty_reviews.csv"
jsonl_to_csv(input_filename, output_filename)
print(f"Successfully converted '{input_filename}' to '{output_filename}'")
# Out:
# Successfully converted 'f:\projects\product-recommender\dataset\All_Beauty.jsonl' to 'f:\projects\product-recommender\dataset\Beauty_reviews.csv'

# %%
import pandas as pd
Beauty_reviews_df = pd.read_csv(
    r"f:\projects\product-recommender\dataset\Beauty_reviews.csv")
Beauty_reviews_df
# Out:
#                               UserId        asin parent_asin  \
# 0       AGKHLEW2SOWHNMFQIJGBECAF7INQ  B00YQ6X8EO  B00YQ6X8EO
# 1       AGKHLEW2SOWHNMFQIJGBECAF7INQ  B081TJ8YS3  B081TJ8YS3
# 2       AE74DYR3QUGVPZJ3P7RFWBGIX7XQ  B07PNNCSP9  B097R46CSY
# 3       AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  B09JS339BZ  B09JS339BZ
# 4       AFQLNQNQYFWQZPJQZS6V3NZU4QBQ  B08BZ63GMJ  B08BZ63GMJ
# ...                              ...         ...         ...
# 701523  AFIXGFVEGLMOTMBTJL7H3VSIETDQ  B006YUIWKA  B006YUIWKA
# 701524  AFV7YZFOJF564EZGET5LG45K4QEA  B006YUIWKA  B006YUIWKA
# 701525  AHYDCWDMMVMLBX7FY7M7JKADKRDQ  B06ZZV9MZT  B06ZZV9MZT
# 701526  AF6ZIAEN7TQ2WY5ZL77F6JDPV7XQ  B000HB6VLE  B000HB6VLE
# 701527  AGIYQU6RK6TBKBCMWKVPBPBMMJNA  B0093MXHFG  B0093MXHFG
#
#                                                      Text  TimeStamp  \
# 0       This spray is really nice. It smells really go...        NaN
# 1       This product does what I need it to do, I just...        NaN
# 2                               Smells good, feels great!        NaN
# 3                                          Felt synthetic        NaN
# 4                                                 Love it        NaN
# ...                                                   ...        ...
# 701523    Conditioner is great  shampoo not as I expected        NaN
# 701524  Did not work! Used the whole bottle and my hai...        NaN
# 701525         Product as expected. Shipping was on time.        NaN
# 701526  Not only is it a delicious fragrance, but also...        NaN
# 701527  The conditioner doesn't really make your hair ...        NaN
#
#                                             Title  helpful_vote
# 0       Such a lovely scent but not overpowering.           NaN
# 1          Works great but smells a little weird.           NaN
# 2                                            Yes!           NaN
# 3                               Synthetic feeling           NaN
# 4                                              A+           NaN
# ...                                           ...           ...
# 701523                                 Four Stars           NaN
# 701524                                     Pretty           NaN
# 701525                       Great sunless tanner           NaN
# 701526              The Crown on top is a Ring!!!           NaN
# 701527                   Good Shampoo/Conditioner           NaN
#
# [701528 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
ax = Beauty_reviews_df['Score'].value_counts().sort_index() \
    .plot(kind='bar',
          title='Count of Reviews by Stars',
          figsize=(10, 5))
ax.set_xlabel('Review Stars')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\recom\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 ax = Beauty_reviews_df['Score'].value_counts().sort_index() \
#       3     .plot(kind='bar',
#       4           title='Count of Reviews by Stars',
#       5           figsize=(10, 5))
#       6 ax.set_xlabel('Review Stars')
#       7 plt.show()
#
# File ~\.conda\envs\recom\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\.conda\envs\recom\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Score'
